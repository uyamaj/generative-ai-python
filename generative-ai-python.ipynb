# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•',' *')
  return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))

# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

# %%
import os
os.environ['GOOGLE_API_KEY']='AIzaSyBS6P5sPH9cTJ1egZSqcflLmskgrzR-IVs'

# %%
# GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
model = genai.GenerativeModel('gemini-pro')
print(model)
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %% [markdown]
# ## Generate text

# %%
response = model.generate_content("What is the future of Generative AI?")
print(response.text)
# Out:
# **Future of Generative AI**
#
# **Advancements in Model Architecture:**
# * Development of more sophisticated transformer architectures, such as GPT-5 and beyond, enabling even larger models with increased capabilities.
# * Exploration of novel model topologies, such as generative adversarial networks (GANs) and variational autoencoders (VAEs), to improve generation quality and diversity.
#
# **Enhanced Generative Capabilities:**
# * Generation of highly realistic images, videos, and audio that are indistinguishable from human-created content.
# * Creation of novel materials, molecules, and artistic works with unique properties and designs.
# * Personalized and adaptive content generation tailored to individual preferences and contexts.
#
# **Integration with Real-World Applications:**
# * Automated content creation for marketing, entertainment, education, and healthcare.
# * Generation of synthetic data for model training and testing in various domains.
# * Design and development of new products and services based on generative models.
#
# **Ethical Considerations and Regulations:**
# * Development of ethical guidelines and regulations to address potential biases, misuse, and societal impacts of generative AI.
# * Exploration of techniques for mitigating deepfakes, misinformation, and other ethical concerns.
#
# **Collaboration and Open Source Development:**
# * Continued collaboration between researchers, industry, and open source communities to foster innovation and progress.
# * Sharing of models, datasets, and knowledge to accelerate the development and adoption of generative AI.
#
# **Long-Term Impact:**
# * Transformation of industries and society through the creation of new jobs, industries, and artistic forms.
# * Empowerment of individuals to create and express themselves through the use of generative AI tools.
# * Potential for disruptive innovation in areas such as healthcare, education, and entertainment.
#
# **Specific Applications:**
#
# * **Image Synthesis:** Highly realistic image generation for gaming, film, and marketing.
# * **Text Generation:** Natural language processing tasks such as writing, summarization, and translation.
# * **Music Generation:** Creation of novel music compositions for various genres and styles.
# * **Video Generation:** Generation of synthetic videos for training, entertainment, and storytelling.
# * **3D Model Creation:** Production of high-fidelity 3D models for architecture, design, and manufacturing.

# %%
response = model.generate_content("Write a story about a magic backpack.")
print(response.text)
# Out:
# In a quaint town nestled amidst verdant hills, there lived a young girl named Anya. Her heart yearned for adventure and the unknown, but her life was rather mundane until fate intervened.
#
# One ordinary morning, as Anya skipped through the flea market, her eyes were drawn to an unassuming backpack hidden among a dusty pile of trinkets. Its leather was soft and worn, adorned with intricate carvings that seemed to whisper ancient secrets. Curiosity sparked within her, and she couldn't resist picking it up.
#
# As Anya slung the backpack over her shoulder, a faint shimmer danced through the air. Suddenly, she felt an overwhelming surge of energy coursing through her. She looked down at the backpack in astonishment, realizing it was no ordinary accessory.
#
# Driven by an insatiable desire to explore, Anya ventured into the nearby forest. As she walked, the backpack seemed to grow lighter and more responsive. It expanded to accommodate all her belongings, from her favorite books to a small bag of snacks.
#
# As the sun dipped below the horizon, Anya stumbled upon a hidden waterfall. Exhausted, she sat down to rest. As she reached into the backpack for her canteen, her hand brushed against something unexpected.
#
# Nestled among her belongings was a small, shimmering key. Anya's heart skipped a beat as she realized the key held the power to unlock the backpack's true magic. She hesitated for a moment, torn between fear and the allure of the unknown.
#
# With trembling hands, Anya inserted the key into the backpack's zipper. As she turned it, an iridescent light filled the forest, illuminating the path ahead. To her amazement, the backpack transformed into a portal, swirling with vibrant colors and promising endless possibilities.
#
# Eager to embrace the adventure that awaited her, Anya stepped through the portal. She found herself in a surreal land filled with talking animals, towering mountains, and enchanting rivers. In this magical realm, the boundaries of reality blurred, and anything seemed possible.
#
# Anya's journey through the backpack's portal became an extraordinary odyssey. She encountered wise old creatures, overcame thrilling challenges, and forged friendships that would last a lifetime. As she explored this wondrous world, Anya discovered the true power of her magic backpack. It was not merely an accessory but a symbol of her boundless imagination, her thirst for adventure, and the infinite possibilities that lie within us all.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import PIL.Image
img = PIL.Image.open('/cat.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x407>

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
print(model)
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response = model.generate_content(img)
print(response.text)
# Out:
# This is a cute image of a kitten playing with a toy. The kitten is focused on the toy and its tail is curled around its body. The kitten is in a well-lit room with hardwood floors. The image is taken from a slightly elevated angle, giving the viewer a good view of the kitten and its toy.

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001-tuning
